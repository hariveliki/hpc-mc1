# %%
# !pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in /opt/conda/lib/python3.10/site-packages (2.0.2)

# %%
from kafka import KafkaConsumer, KafkaProducer
import json
import uuid
import random
import time
import cProfile
import os
import pstats
from pstats import SortKey

# %%
def connect_kafka_producer(servers):
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=servers, api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer

# %%
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully.')
    except Exception as ex:
        print('Exception in publishing message')
        print(str(ex))

# %%
def produce_xy(producer, topic_name):
    cwd = os.getcwd()
    with open("data.json") as file:
        data = json.load(file)
    len_max = len(data)
    n_get = 0
    n_item = 1
    while True:
        if n_get == len_max:
            n_get = 0
        product = data[n_get]
        message = json.dumps({"product": product})
        publish_message(producer, topic_name, str(uuid.uuid4()), message)
        print("Published items so far: {}".format(n_item))
        time.sleep(0.5)
        n_item += 1
        n_get += 1

# %%
servers = ['broker1:9093', 'broker2:9094', 'broker3:9095']
topic = "products"

producer = connect_kafka_producer(servers)
produce_xy(producer, topic)
# Out:
# Message published successfully.
# Published items so far: 1
# Message published successfully.
# Published items so far: 2
# Message published successfully.
# Published items so far: 3
# Message published successfully.
# Published items so far: 4
# Message published successfully.
# Published items so far: 5
# Message published successfully.
# Published items so far: 6
# Message published successfully.
# Published items so far: 7
# Message published successfully.
# Published items so far: 8
# Message published successfully.
# Published items so far: 9
# Message published successfully.
# Published items so far: 10
# Message published successfully.
# Published items so far: 11
# Message published successfully.
# Published items so far: 12
# Message published successfully.
# Published items so far: 13
# Message published successfully.
# Published items so far: 14
# Message published successfully.
# Published items so far: 15
# Message published successfully.
# Published items so far: 16
# Message published successfully.
# Published items so far: 17
# Message published successfully.
# Published items so far: 18
# Message published successfully.
# Published items so far: 19
# Message published successfully.
# Published items so far: 20
# Message published successfully.
# Published items so far: 21
# Message published successfully.
# Published items so far: 22
# Message published successfully.
# Published items so far: 23
# Message published successfully.
# Published items so far: 24
# Message published successfully.
# Published items so far: 25
# Message published successfully.
# Published items so far: 26
# Message published successfully.
# Published items so far: 27
# Message published successfully.
# Published items so far: 28
# Message published successfully.
# Published items so far: 29
# Message published successfully.
# Published items so far: 30
# Message published successfully.
# Published items so far: 31
# Message published successfully.
# Published items so far: 32
# Message published successfully.
# Published items so far: 33
# Message published successfully.
# Published items so far: 34
# Message published successfully.
# Published items so far: 35
# Message published successfully.
# Published items so far: 36
# Message published successfully.
# Published items so far: 37
# Message published successfully.
# Published items so far: 38
# Message published successfully.
# Published items so far: 39
# Message published successfully.
# Published items so far: 40
# Message published successfully.
# Published items so far: 41
# Message published successfully.
# Published items so far: 42
# Message published successfully.
# Published items so far: 43
# Message published successfully.
# Published items so far: 44
# Message published successfully.
# Published items so far: 45
# Message published successfully.
# Published items so far: 46
# Message published successfully.
# Published items so far: 47
# Message published successfully.
# Published items so far: 48
# Message published successfully.
# Published items so far: 49
# Message published successfully.
# Published items so far: 50
# Message published successfully.
# Published items so far: 51
# Message published successfully.
# Published items so far: 52
# Message published successfully.
# Published items so far: 53
# Message published successfully.
# Published items so far: 54
# Message published successfully.
# Published items so far: 55
# Message published successfully.
# Published items so far: 56
# Message published successfully.
# Published items so far: 57
# Message published successfully.
# Published items so far: 58
# Message published successfully.
# Published items so far: 59
# Message published successfully.
# Published items so far: 60
# Message published successfully.
# Published items so far: 61
# Message published successfully.
# Published items so far: 62
# Message published successfully.
# Published items so far: 63
# Message published successfully.
# Published items so far: 64
# Message published successfully.
# Published items so far: 65
# Message published successfully.
# Published items so far: 66
# Message published successfully.
# Published items so far: 67
# Message published successfully.
# Published items so far: 68
# Message published successfully.
# Published items so far: 69
# Message published successfully.
# Published items so far: 70
# Message published successfully.
# Published items so far: 71
# Message published successfully.
# Published items so far: 72
# Message published successfully.
# Published items so far: 73
# Message published successfully.
# Published items so far: 74
# Message published successfully.
# Published items so far: 75
# Message published successfully.
# Published items so far: 76
# Message published successfully.
# Published items so far: 77
# Message published successfully.
# Published items so far: 78
# Message published successfully.
# Published items so far: 79
# Message published successfully.
# Published items so far: 80
# Message published successfully.
# Published items so far: 81
# Message published successfully.
# Published items so far: 82
# Message published successfully.
# Published items so far: 83
# Message published successfully.
# Published items so far: 84
# Message published successfully.
# Published items so far: 85
# Message published successfully.
# Published items so far: 86
# Message published successfully.
# Published items so far: 87
# Message published successfully.
# Published items so far: 88
# Message published successfully.
# Published items so far: 89
# Message published successfully.
# Published items so far: 90
# Message published successfully.
# Published items so far: 91
# Message published successfully.
# Published items so far: 92
# Message published successfully.
# Published items so far: 93
# Message published successfully.
# Published items so far: 94
# Message published successfully.
# Published items so far: 95
# Message published successfully.
# Published items so far: 96
# Message published successfully.
# Published items so far: 97
# Message published successfully.
# Published items so far: 98
# Message published successfully.
# Published items so far: 99
# Message published successfully.
# Published items so far: 100
# Message published successfully.
# Published items so far: 101
# Message published successfully.
# Published items so far: 102
# Message published successfully.
# Published items so far: 103
# Message published successfully.
# Published items so far: 104
# Message published successfully.
# Published items so far: 105
# Message published successfully.
# Published items so far: 106
# Message published successfully.
# Published items so far: 107
# Message published successfully.
# Published items so far: 108
# Message published successfully.
# Published items so far: 109
# Message published successfully.
# Published items so far: 110
# Message published successfully.
# Published items so far: 111
# Message published successfully.
# Published items so far: 112
# Message published successfully.
# Published items so far: 113
# Message published successfully.
# Published items so far: 114
# Message published successfully.
# Published items so far: 115
# Message published successfully.
# Published items so far: 116
# Message published successfully.
# Published items so far: 117
# Message published successfully.
# Published items so far: 118
# Message published successfully.
# Published items so far: 119
# Message published successfully.
# Published items so far: 120
# Message published successfully.
# Published items so far: 121
# Message published successfully.
# Published items so far: 122
# Message published successfully.
# Published items so far: 123
# Message published successfully.
# Published items so far: 124
# Message published successfully.
# Published items so far: 125
# Message published successfully.
# Published items so far: 126
# Message published successfully.
# Published items so far: 127
# Message published successfully.
# Published items so far: 128
# Message published successfully.
# Published items so far: 129
# Message published successfully.
# Published items so far: 130
# Message published successfully.
# Published items so far: 131
# Message published successfully.
# Published items so far: 132
# Message published successfully.
# Published items so far: 133
# Message published successfully.
# Published items so far: 134
# Message published successfully.
# Published items so far: 135
# Message published successfully.
# Published items so far: 136
# Message published successfully.
# Published items so far: 137
# Message published successfully.
# Published items so far: 138
# Message published successfully.
# Published items so far: 139
# Message published successfully.
# Published items so far: 140
# Message published successfully.
# Published items so far: 141
# Message published successfully.
# Published items so far: 142
# Message published successfully.
# Published items so far: 143
# Message published successfully.
# Published items so far: 144
# Message published successfully.
# Published items so far: 145
# Message published successfully.
# Published items so far: 146
# Message published successfully.
# Published items so far: 147
# Message published successfully.
# Published items so far: 148
# Message published successfully.
# Published items so far: 149
# Message published successfully.
# Published items so far: 150
# Message published successfully.
# Published items so far: 151
# Message published successfully.
# Published items so far: 152
# Message published successfully.
# Published items so far: 153
# Message published successfully.
# Published items so far: 154
# Message published successfully.
# Published items so far: 155
# Message published successfully.
# Published items so far: 156
# Message published successfully.
# Published items so far: 157
# Message published successfully.
# Published items so far: 158
# Message published successfully.
# Published items so far: 159
# Message published successfully.
# Published items so far: 160
# Message published successfully.
# Published items so far: 161
# Message published successfully.
# Published items so far: 162
# Message published successfully.
# Published items so far: 163
# Message published successfully.
# Published items so far: 164
# Message published successfully.
# Published items so far: 165
# Message published successfully.
# Published items so far: 166
# Message published successfully.
# Published items so far: 167
# Message published successfully.
# Published items so far: 168
# Message published successfully.
# Published items so far: 169
# Message published successfully.
# Published items so far: 170
# Message published successfully.
# Published items so far: 171
# Message published successfully.
# Published items so far: 172
# Message published successfully.
# Published items so far: 173
# Message published successfully.
# Published items so far: 174
# Message published successfully.
# Published items so far: 175
# Message published successfully.
# Published items so far: 176
# Message published successfully.
# Published items so far: 177
# Message published successfully.
# Published items so far: 178
# Message published successfully.
# Published items so far: 179
# Message published successfully.
# Published items so far: 180
# Message published successfully.
# Published items so far: 181
# Message published successfully.
# Published items so far: 182
# Message published successfully.
# Published items so far: 183
# Message published successfully.
# Published items so far: 184
# Message published successfully.
# Published items so far: 185
# Message published successfully.
# Published items so far: 186
# Message published successfully.
# Published items so far: 187
# Message published successfully.
# Published items so far: 188
# Message published successfully.
# Published items so far: 189
# Message published successfully.
# Published items so far: 190
# Message published successfully.
# Published items so far: 191
# Message published successfully.
# Published items so far: 192
# Message published successfully.
# Published items so far: 193
# Message published successfully.
# Published items so far: 194
# Message published successfully.
# Published items so far: 195
# Message published successfully.
# Published items so far: 196
# Message published successfully.
# Published items so far: 197
# Message published successfully.
# Published items so far: 198
# Message published successfully.
# Published items so far: 199
# Message published successfully.
# Published items so far: 200
# Message published successfully.
# Published items so far: 201
# Message published successfully.
# Published items so far: 202
# Message published successfully.
# Published items so far: 203
# Message published successfully.
# Published items so far: 204
# Message published successfully.
# Published items so far: 205
# Message published successfully.
# Published items so far: 206
# Message published successfully.
# Published items so far: 207
# Message published successfully.
# Published items so far: 208
# Message published successfully.
# Published items so far: 209
# Message published successfully.
# Published items so far: 210
# Message published successfully.
# Published items so far: 211
# Message published successfully.
# Published items so far: 212
# Message published successfully.
# Published items so far: 213
# Message published successfully.
# Published items so far: 214
# Message published successfully.
# Published items so far: 215
# Message published successfully.
# Published items so far: 216
# Message published successfully.
# Published items so far: 217
# Message published successfully.
# Published items so far: 218
# Message published successfully.
# Published items so far: 219
# Message published successfully.
# Published items so far: 220
# Message published successfully.
# Published items so far: 221
# Message published successfully.
# Published items so far: 222
# Message published successfully.
# Published items so far: 223
# Message published successfully.
# Published items so far: 224
# Message published successfully.
# Published items so far: 225
# Message published successfully.
# Published items so far: 226
# Message published successfully.
# Published items so far: 227
# Message published successfully.
# Published items so far: 228
# Message published successfully.
# Published items so far: 229
# Message published successfully.
# Published items so far: 230
# Message published successfully.
# Published items so far: 231
# Message published successfully.
# Published items so far: 232
# Message published successfully.
# Published items so far: 233
# Message published successfully.
# Published items so far: 234
# Message published successfully.
# Published items so far: 235
# Message published successfully.
# Published items so far: 236
# Message published successfully.
# Published items so far: 237
# Message published successfully.
# Published items so far: 238
# Message published successfully.
# Published items so far: 239
# Message published successfully.
# Published items so far: 240
# Message published successfully.
# Published items so far: 241
# Message published successfully.
# Published items so far: 242
# Message published successfully.
# Published items so far: 243
# Message published successfully.
# Published items so far: 244
# Message published successfully.
# Published items so far: 245
# Message published successfully.
# Published items so far: 246
# Message published successfully.
# Published items so far: 247
# Message published successfully.
# Published items so far: 248
# Message published successfully.
# Published items so far: 249
# Message published successfully.
# Published items so far: 250
# Message published successfully.
# Published items so far: 251
# Message published successfully.
# Published items so far: 252
# Message published successfully.
# Published items so far: 253
# Message published successfully.
# Published items so far: 254
# Message published successfully.
# Published items so far: 255
# Message published successfully.
# Published items so far: 256
# Message published successfully.
# Published items so far: 257
# Message published successfully.
# Published items so far: 258
# Message published successfully.
# Published items so far: 259
# Message published successfully.
# Published items so far: 260
# Message published successfully.
# Published items so far: 261
# Message published successfully.
# Published items so far: 262
# Message published successfully.
# Published items so far: 263
# Message published successfully.
# Published items so far: 264
# Message published successfully.
# Published items so far: 265
# Message published successfully.
# Published items so far: 266
# Message published successfully.
# Published items so far: 267
# Message published successfully.
# Published items so far: 268
# Message published successfully.
# Published items so far: 269
# Message published successfully.
# Published items so far: 270
# Message published successfully.
# Published items so far: 271
# Message published successfully.
# Published items so far: 272
# Message published successfully.
# Published items so far: 273
# Message published successfully.
# Published items so far: 274
# Message published successfully.
# Published items so far: 275
# Message published successfully.
# Published items so far: 276
# Message published successfully.
# Published items so far: 277
# Message published successfully.
# Published items so far: 278
# Message published successfully.
# Published items so far: 279
# Message published successfully.
# Published items so far: 280
# Message published successfully.
# Published items so far: 281
# Message published successfully.
# Published items so far: 282
# Message published successfully.
# Published items so far: 283
# Message published successfully.
# Published items so far: 284
# Message published successfully.
# Published items so far: 285
# Message published successfully.
# Published items so far: 286
# Message published successfully.
# Published items so far: 287
# Message published successfully.
# Published items so far: 288
# Message published successfully.
# Published items so far: 289
# Message published successfully.
# Published items so far: 290
# Message published successfully.
# Published items so far: 291
# Message published successfully.
# Published items so far: 292
# Message published successfully.
# Published items so far: 293
# Message published successfully.
# Published items so far: 294
# Message published successfully.
# Published items so far: 295
# Message published successfully.
# Published items so far: 296
# Message published successfully.
# Published items so far: 297
# Message published successfully.
# Published items so far: 298
# Message published successfully.
# Published items so far: 299
# Message published successfully.
# Published items so far: 300
# Message published successfully.
# Published items so far: 301
# Message published successfully.
# Published items so far: 302
# Message published successfully.
# Published items so far: 303
# Message published successfully.
# Published items so far: 304
# Message published successfully.
# Published items so far: 305
# Message published successfully.
# Published items so far: 306
# Message published successfully.
# Published items so far: 307
# Message published successfully.
# Published items so far: 308
# Message published successfully.
# Published items so far: 309
# Message published successfully.
# Published items so far: 310
# Message published successfully.
# Published items so far: 311
# Message published successfully.
# Published items so far: 312
# Message published successfully.
# Published items so far: 313
# Message published successfully.
# Published items so far: 314
# Message published successfully.
# Published items so far: 315
# Message published successfully.
# Published items so far: 316
# Message published successfully.
# Published items so far: 317
# Message published successfully.
# Published items so far: 318
# Message published successfully.
# Published items so far: 319
# Message published successfully.
# Published items so far: 320
# Message published successfully.
# Published items so far: 321
# Message published successfully.
# Published items so far: 322
# Message published successfully.
# Published items so far: 323
# Message published successfully.
# Published items so far: 324
# Message published successfully.
# Published items so far: 325
# Message published successfully.
# Published items so far: 326
# Message published successfully.
# Published items so far: 327
# Message published successfully.
# Published items so far: 328
# Message published successfully.
# Published items so far: 329
# Message published successfully.
# Published items so far: 330
# Message published successfully.
# Published items so far: 331
# Message published successfully.
# Published items so far: 332
# Message published successfully.
# Published items so far: 333
# Message published successfully.
# Published items so far: 334
# Message published successfully.
# Published items so far: 335
# Message published successfully.
# Published items so far: 336
# Message published successfully.
# Published items so far: 337
# Message published successfully.
# Published items so far: 338
# Message published successfully.
# Published items so far: 339
# Message published successfully.
# Published items so far: 340
# Message published successfully.
# Published items so far: 341
# Message published successfully.
# Published items so far: 342
# Message published successfully.
# Published items so far: 343
# Message published successfully.
# Published items so far: 344
# Message published successfully.
# Published items so far: 345
# Message published successfully.
# Published items so far: 346
# Message published successfully.
# Published items so far: 347
# Message published successfully.
# Published items so far: 348
# Message published successfully.
# Published items so far: 349
# Message published successfully.
# Published items so far: 350
# Message published successfully.
# Published items so far: 351
# Message published successfully.
# Published items so far: 352
# Message published successfully.
# Published items so far: 353
# Message published successfully.
# Published items so far: 354
# Message published successfully.
# Published items so far: 355
# Message published successfully.
# Published items so far: 356
# Message published successfully.
# Published items so far: 357
# Message published successfully.
# Published items so far: 358
# Message published successfully.
# Published items so far: 359
# Message published successfully.
# Published items so far: 360
# Message published successfully.
# Published items so far: 361
# Message published successfully.
# Published items so far: 362
# Message published successfully.
# Published items so far: 363
# Message published successfully.
# Published items so far: 364
# Message published successfully.
# Published items so far: 365
# Message published successfully.
# Published items so far: 366
# Message published successfully.
# Published items so far: 367
# Message published successfully.
# Published items so far: 368
# Message published successfully.
# Published items so far: 369
# Message published successfully.
# Published items so far: 370
# Message published successfully.
# Published items so far: 371
# Message published successfully.
# Published items so far: 372
# Message published successfully.
# Published items so far: 373
# Message published successfully.
# Published items so far: 374
# Message published successfully.
# Published items so far: 375
# Message published successfully.
# Published items so far: 376
# Message published successfully.
# Published items so far: 377
# Message published successfully.
# Published items so far: 378
# Message published successfully.
# Published items so far: 379
# Message published successfully.
# Published items so far: 380
# Message published successfully.
# Published items so far: 381
# Message published successfully.
# Published items so far: 382
# Message published successfully.
# Published items so far: 383
# Message published successfully.
# Published items so far: 384
# Message published successfully.
# Published items so far: 385
# Message published successfully.
# Published items so far: 386
# Message published successfully.
# Published items so far: 387
# Message published successfully.
# Published items so far: 388
# Message published successfully.
# Published items so far: 389
# Message published successfully.
# Published items so far: 390
# Message published successfully.
# Published items so far: 391
# Message published successfully.
# Published items so far: 392
# Message published successfully.
# Published items so far: 393
# Message published successfully.
# Published items so far: 394
# Message published successfully.
# Published items so far: 395
# Message published successfully.
# Published items so far: 396
# Message published successfully.
# Published items so far: 397
# Message published successfully.
# Published items so far: 398
# Message published successfully.
# Published items so far: 399
# Message published successfully.
# Published items so far: 400
# Message published successfully.
# Published items so far: 401
# Message published successfully.
# Published items so far: 402
# Message published successfully.
# Published items so far: 403
# Message published successfully.
# Published items so far: 404
# Message published successfully.
# Published items so far: 405
# Message published successfully.
# Published items so far: 406
# Message published successfully.
# Published items so far: 407
# Message published successfully.
# Published items so far: 408
# Message published successfully.
# Published items so far: 409
# Message published successfully.
# Published items so far: 410
# Message published successfully.
# Published items so far: 411
# Message published successfully.
# Published items so far: 412
# Message published successfully.
# Published items so far: 413
# Message published successfully.
# Published items so far: 414
# Message published successfully.
# Published items so far: 415
# Message published successfully.
# Published items so far: 416
# Message published successfully.
# Published items so far: 417
# Message published successfully.
# Published items so far: 418
# Message published successfully.
# Published items so far: 419
# Message published successfully.
# Published items so far: 420
# Message published successfully.
# Published items so far: 421
# Message published successfully.
# Published items so far: 422
# Message published successfully.
# Published items so far: 423
# Message published successfully.
# Published items so far: 424
# Message published successfully.
# Published items so far: 425
# Message published successfully.
# Published items so far: 426
# Message published successfully.
# Published items so far: 427
# Message published successfully.
# Published items so far: 428
# Message published successfully.
# Published items so far: 429
# Message published successfully.
# Published items so far: 430
# Message published successfully.
# Published items so far: 431
# Message published successfully.
# Published items so far: 432
# Message published successfully.
# Published items so far: 433
# Message published successfully.
# Published items so far: 434
# Message published successfully.
# Published items so far: 435
# Message published successfully.
# Published items so far: 436
# Message published successfully.
# Published items so far: 437
# Message published successfully.
# Published items so far: 438
# Message published successfully.
# Published items so far: 439
# Message published successfully.
# Published items so far: 440
# Message published successfully.
# Published items so far: 441
# Message published successfully.
# Published items so far: 442
# Message published successfully.
# Published items so far: 443
# Message published successfully.
# Published items so far: 444
# Message published successfully.
# Published items so far: 445
# Message published successfully.
# Published items so far: 446
# Message published successfully.
# Published items so far: 447
# Message published successfully.
# Published items so far: 448
# Message published successfully.
# Published items so far: 449
# Message published successfully.
# Published items so far: 450
# Message published successfully.
# Published items so far: 451
# Message published successfully.
# Published items so far: 452
# Message published successfully.
# Published items so far: 453
# Message published successfully.
# Published items so far: 454
# Message published successfully.
# Published items so far: 455
# Message published successfully.
# Published items so far: 456
# Message published successfully.
# Published items so far: 457
# Message published successfully.
# Published items so far: 458
# Message published successfully.
# Published items so far: 459
# Message published successfully.
# Published items so far: 460
# Message published successfully.
# Published items so far: 461
# Message published successfully.
# Published items so far: 462
# Message published successfully.
# Published items so far: 463
# Message published successfully.
# Published items so far: 464
# Message published successfully.
# Published items so far: 465
# Message published successfully.
# Published items so far: 466
# Message published successfully.
# Published items so far: 467
# Message published successfully.
# Published items so far: 468
# Message published successfully.
# Published items so far: 469
# Message published successfully.
# Published items so far: 470
# Message published successfully.
# Published items so far: 471
# Message published successfully.
# Published items so far: 472
# Message published successfully.
# Published items so far: 473
# Message published successfully.
# Published items so far: 474
# Message published successfully.
# Published items so far: 475
# Message published successfully.
# Published items so far: 476
# Message published successfully.
# Published items so far: 477
# Message published successfully.
# Published items so far: 478
# Message published successfully.
# Published items so far: 479
# Message published successfully.
# Published items so far: 480
# Message published successfully.
# Published items so far: 481
# Message published successfully.
# Published items so far: 482
# Message published successfully.
# Published items so far: 483
# Message published successfully.
# Published items so far: 484
# Message published successfully.
# Published items so far: 485
# Message published successfully.
# Published items so far: 486
# Message published successfully.
# Published items so far: 487
# Message published successfully.
# Published items so far: 488
# Message published successfully.
# Published items so far: 489
# Message published successfully.
# Published items so far: 490
# Message published successfully.
# Published items so far: 491
# Message published successfully.
# Published items so far: 492
# Message published successfully.
# Published items so far: 493
# Message published successfully.
# Published items so far: 494
# Message published successfully.
# Published items so far: 495
# Message published successfully.
# Published items so far: 496
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 topic = "products"
#       4 producer = connect_kafka_producer(servers)
# ----> 5 produce_xy(producer, topic)
#
# Cell In[5], line 15, in produce_xy(producer, topic_name)
#      13 publish_message(producer, topic_name, str(uuid.uuid4()), message)
#      14 print("Published items so far: {}".format(n_item))
# ---> 15 time.sleep(0.5)
#      16 n_item += 1
#      17 n_get += 1
#
# KeyboardInterrupt:

# %% [markdown]
# # Ignore below

# %%
# cProfile.run("connect_kafka_producer(server1)", "mc1-part1/connect_kafka")
# p = pstats.Stats("mc1-part1/connect_kafka")
# p.sort_stats(SortKey.TIME)
# p.print_stats()

# %%
# cProfile.run("produce_xy(producer, topic)", "mc1-part1/produce_stats")

# %%
# p = pstats.Stats("mc1-part1/produce_stats")
# p.sort_stats(SortKey.TIME)
# p.print_stats(10)
