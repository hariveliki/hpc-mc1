# %%
# !pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in /opt/conda/lib/python3.10/site-packages (2.0.2)

# %%
from kafka import KafkaConsumer, KafkaProducer
import json
import uuid
import random
import time
import cProfile

# %%
def connect_kafka_producer(servers):
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=servers, api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer

# %%
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully.')
    except Exception as ex:
        print('Exception in publishing message')
        print(str(ex))

# %%
def produce_xy(producer, topic_name):
    while True:
        name = f'Mark {random.randint(0,22)}'
        message = json.dumps({"name": name})
        print(name)
        publish_message(producer, topic_name, str(uuid.uuid4()), message)
        time.sleep(1)

# %%
server1 = 'broker1:9093'
topic1 = "names"

producer = connect_kafka_producer(server1)

# %%
cProfile.run("produce_xy(producer, topic1)")
# Out:
# Mark 22
# Message published successfully.
# Mark 4
# Message published successfully.
# Mark 5
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 14
# Message published successfully.
# Mark 11
# Message published successfully.
# Mark 20
# Message published successfully.
# Mark 1
# Message published successfully.
# Mark 8
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 11
# Message published successfully.
# Mark 9
# Message published successfully.
# Mark 15
# Message published successfully.
# Mark 20
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 6
# Message published successfully.
# Mark 15
# Message published successfully.
# Mark 4
# Message published successfully.
# Mark 7
# Message published successfully.
# Mark 4
# Message published successfully.
# Mark 14
# Message published successfully.
# Mark 1
# Message published successfully.
# Mark 15
# Message published successfully.
# Mark 21
# Message published successfully.
# Mark 14
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 15
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 8
# Message published successfully.
# Mark 22
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 7
# Message published successfully.
# Mark 5
# Message published successfully.
# Mark 0
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 8
# Message published successfully.
# Mark 9
# Message published successfully.
# Mark 17
# Message published successfully.
# Mark 4
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 16
# Message published successfully.
# Mark 8
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 22
# Message published successfully.
# Mark 6
# Message published successfully.
# Mark 8
# Message published successfully.
# Mark 14
# Message published successfully.
# Mark 3
# Message published successfully.
# Mark 1
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 20
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 14
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 1
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 8
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 5
# Message published successfully.
# Mark 22
# Message published successfully.
# Mark 3
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 9
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 4
# Message published successfully.
# Mark 0
# Message published successfully.
# Mark 11
# Message published successfully.
# Mark 11
# Message published successfully.
# Mark 6
# Message published successfully.
# Mark 4
# Message published successfully.
# Mark 22
# Message published successfully.
# Mark 21
# Message published successfully.
# Mark 13
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 11
# Message published successfully.
# Mark 4
# Message published successfully.
# Mark 1
# Message published successfully.
# Mark 7
# Message published successfully.
# Mark 0
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 14
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 9
# Message published successfully.
# Mark 14
# Message published successfully.
# Mark 16
# Message published successfully.
# Mark 1
# Message published successfully.
# Mark 13
# Message published successfully.
# Mark 6
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 1
# Message published successfully.
# Mark 21
# Message published successfully.
# Mark 11
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 5
# Message published successfully.
# Mark 5
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 9
# Message published successfully.
# Mark 6
# Message published successfully.
# Mark 22
# Message published successfully.
# Mark 16
# Message published successfully.
# Mark 11
# Message published successfully.
# Mark 17
# Message published successfully.
# Mark 3
# Message published successfully.
# Mark 14
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 6
# Message published successfully.
# Mark 5
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 20
# Message published successfully.
# Mark 10
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 22
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 9
# Message published successfully.
# Mark 5
# Message published successfully.
# Mark 16
# Message published successfully.
# Mark 1
# Message published successfully.
# Mark 5
# Message published successfully.
# Mark 13
# Message published successfully.
# Mark 20
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 13
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 13
# Message published successfully.
# Mark 4
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 4
# Message published successfully.
# Mark 9
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 3
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 13
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 13
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 8
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 22
# Message published successfully.
# Mark 1
# Message published successfully.
# Mark 6
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 17
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 6
# Message published successfully.
# Mark 2
# Message published successfully.
# Mark 19
# Message published successfully.
# Mark 9
# Message published successfully.
# Mark 15
# Message published successfully.
# Mark 21
# Message published successfully.
# Mark 18
# Message published successfully.
# Mark 12
# Message published successfully.
# Mark 6
# Message published successfully.
# Mark 8
# Message published successfully.
# Mark 5
# Message published successfully.
# Mark 3
# Message published successfully.
# Mark 12
# Message published successfully.
#          37337 function calls in 178.442 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.010    0.010  178.442  178.442 2670055886.py:1(produce_xy)
#       177    0.002    0.000    1.484    0.008 661153088.py:1(publish_message)
#       177    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000  178.442  178.442 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1307(disable)
#       889    0.001    0.000    0.002    0.000 __init__.py:1455(debug)
#         1    0.000    0.000    0.000    0.000 __init__.py:1710(getEffectiveLevel)
#       889    0.001    0.000    0.001    0.000 __init__.py:1724(isEnabledFor)
#       177    0.001    0.000    0.010    0.000 __init__.py:183(dumps)
#         1    0.000    0.000    0.000    0.000 __init__.py:219(_acquireLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#       177    0.001    0.000    0.001    0.000 buffer.py:38(allocate)
#       357    0.001    0.000    0.070    0.000 client_async.py:929(wakeup)
#       356    0.002    0.000    0.002    0.000 cluster.py:106(partitions_for_topic)
#       177    0.001    0.000    0.002    0.000 cluster.py:119(available_partitions_for_topic)
#       177    0.000    0.000    0.000    0.000 cluster.py:131(<listcomp>)
#         2    0.000    0.000    0.000    0.000 cluster.py:185(request_update)
#       177    0.001    0.000    0.015    0.000 default.py:15(__call__)
#       177    0.014    0.000    0.014    0.000 default.py:36(murmur2)
#       177    0.002    0.000    0.010    0.000 encoder.py:182(encode)
#       177    0.007    0.000    0.007    0.000 encoder.py:204(iterencode)
#       177    0.001    0.000    0.006    0.000 future.py:11(__init__)
#       356    0.001    0.000    0.001    0.000 future.py:12(__init__)
#       177    0.000    0.000    0.000    0.000 future.py:22(failed)
#       177    0.000    0.000    1.184    0.007 future.py:26(wait)
#       177    0.001    0.000    0.002    0.000 future.py:32(__init__)
#       179    0.000    0.000    0.000    0.000 future.py:48(add_callback)
#       179    0.000    0.000    0.000    0.000 future.py:57(add_errback)
#         2    0.000    0.000    0.000    0.000 future.py:66(add_both)
#       177    0.003    0.000    0.019    0.000 iostream.py:203(schedule)
#       708    0.002    0.000    0.003    0.000 iostream.py:444(_is_master_process)
#       708    0.001    0.000    0.021    0.000 iostream.py:465(_schedule_flush)
#       708    0.006    0.000    0.031    0.000 iostream.py:535(write)
#       177    0.001    0.000    0.001    0.000 iostream.py:90(_event_pipe)
#       177    0.000    0.000    0.000    0.000 kafka.py:521(_max_usable_produce_magic)
#       177    0.001    0.000    0.003    0.000 kafka.py:529(_estimate_size_in_bytes)
#       177    0.009    0.000    0.280    0.002 kafka.py:538(send)
#       177    0.000    0.000    0.000    0.000 kafka.py:593(<genexpr>)
#       177    0.001    0.000    1.199    0.007 kafka.py:624(flush)
#       177    0.000    0.000    0.000    0.000 kafka.py:651(_ensure_valid_record_size)
#       177    0.001    0.000    0.127    0.001 kafka.py:664(_wait_on_metadata)
#       354    0.000    0.000    0.000    0.000 kafka.py:709(_serialize)
#       177    0.001    0.000    0.019    0.000 kafka.py:716(_partition)
#       177    0.000    0.000    0.000    0.000 legacy_records.py:346(__init__)
#       177    0.025    0.000    0.034    0.000 legacy_records.py:352(append)
#       177    0.003    0.000    0.008    0.000 legacy_records.py:391(_encode_msg)
#       177    0.000    0.000    0.000    0.000 legacy_records.py:472(size)
#       177    0.000    0.000    0.001    0.000 legacy_records.py:479(size_in_bytes)
#       354    0.001    0.000    0.001    0.000 legacy_records.py:486(record_size)
#       354    0.000    0.000    0.000    0.000 legacy_records.py:495(record_overhead)
#       177    0.001    0.000    0.002    0.000 legacy_records.py:503(estimate_size_in_bytes)
#       177    0.000    0.000    0.000    0.000 legacy_records.py:521(__init__)
#       177    0.000    0.000    0.000    0.000 legacy_records.py:527(offset)
#       177    0.000    0.000    0.000    0.000 legacy_records.py:531(crc)
#       177    0.000    0.000    0.000    0.000 legacy_records.py:535(size)
#       177    0.000    0.000    0.000    0.000 legacy_records.py:539(timestamp)
#       177    0.001    0.000    0.002    0.000 memory_records.py:118(__init__)
#       177    0.000    0.000    0.035    0.000 memory_records.py:137(append)
#       177    0.001    0.000    0.001    0.000 memory_records.py:176(is_full)
#       177    0.002    0.000    0.002    0.000 random.py:239(_randbelow_with_getrandbits)
#       177    0.002    0.000    0.006    0.000 random.py:292(randrange)
#       177    0.001    0.000    0.007    0.000 random.py:366(randint)
#       177    0.005    0.000    0.057    0.000 record_accumulator.py:200(append)
#       354    0.001    0.000    0.001    0.000 record_accumulator.py:24(increment)
#       354    0.001    0.000    0.001    0.000 record_accumulator.py:29(decrement)
#       177    0.001    0.000    0.007    0.000 record_accumulator.py:39(__init__)
#       177    0.000    0.000    0.001    0.000 record_accumulator.py:513(begin_flush)
#       177    0.002    0.000    1.187    0.007 record_accumulator.py:520(await_flush_completion)
#       177    0.002    0.000    0.039    0.000 record_accumulator.py:57(try_append)
#       177    0.001    0.000    0.001    0.000 record_accumulator.py:580(add)
#       177    0.001    0.000    0.001    0.000 record_accumulator.py:588(all)
#       177    0.001    0.000    0.001    0.000 sender.py:173(add_topic)
#       357    0.001    0.000    0.071    0.000 sender.py:331(wakeup)
#       177    0.000    0.000    0.001    0.000 six.py:592(iteritems)
#       177    0.011    0.000    0.011    0.000 socket.py:613(send)
#       177    0.000    0.000    0.003    0.000 threading.py:1102(_wait_for_tstate_lock)
#       177    0.001    0.000    0.004    0.000 threading.py:1169(is_alive)
#       178    0.003    0.000    0.003    0.000 threading.py:236(__init__)
#       181    0.000    0.000    0.000    0.000 threading.py:264(__enter__)
#       181    0.000    0.000    0.000    0.000 threading.py:267(__exit__)
#       179    0.000    0.000    0.000    0.000 threading.py:273(_release_save)
#       179    0.000    0.000    0.001    0.000 threading.py:276(_acquire_restore)
#       179    0.000    0.000    0.000    0.000 threading.py:279(_is_owned)
#       179    0.002    0.000    1.304    0.007 threading.py:288(wait)
#       178    0.001    0.000    0.004    0.000 threading.py:545(__init__)
#       179    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#         2    0.000    0.000    0.000    0.000 threading.py:579(clear)
#       179    0.001    0.000    1.306    0.007 threading.py:589(wait)
#       177    0.002    0.000    0.003    0.000 util.py:131(calc_crc32)
#       177    0.003    0.000    0.003    0.000 uuid.py:138(__init__)
#       177    0.002    0.000    0.002    0.000 uuid.py:279(__str__)
#       177    0.001    0.000    0.014    0.000 uuid.py:718(uuid4)
#       177    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0xaaaac65eee58}
#       531    0.001    0.000    0.001    0.000 {built-in method _operator.index}
#       531    0.001    0.000    0.001    0.000 {built-in method _struct.pack_into}
#       358    0.001    0.000    0.001    0.000 {built-in method _thread.allocate_lock}
#       177    0.001    0.000    0.001    0.000 {built-in method binascii.crc32}
#       177    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000  178.442  178.442 {built-in method builtins.exec}
#      1770    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#       177    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#      3186    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#       354    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#       354    0.002    0.000    0.033    0.000 {built-in method builtins.print}
#       177    0.001    0.000    0.001    0.000 {built-in method builtins.sorted}
#       177    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#       708    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#       177    0.009    0.000    0.009    0.000 {built-in method posix.urandom}
#       177  176.886    0.999  176.886    0.999 {built-in method time.sleep}
#       710    0.000    0.000    0.000    0.000 {built-in method time.time}
#       181    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       885    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#      1957    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       893    1.305    0.001    1.305    0.001 {method 'acquire' of '_thread.lock' objects}
#       178    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       533    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       358    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       177    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#       177    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       177    0.000    0.000    0.000    0.000 {method 'extend' of 'bytearray' objects}
#       244    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#       177    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       177    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#       354    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       177    0.000    0.000    0.000    0.000 {method 'pack_into' of '_struct.Struct' objects}
#       177    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       179    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       357    0.069    0.000    0.069    0.000 {method 'sendall' of '_socket.socket' objects}
#       708    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cProfile.run("produce_xy(producer, topic1)")
#
# File /opt/conda/lib/python3.10/cProfile.py:16, in run(statement, filename, sort)
#      15 def run(statement, filename=None, sort=-1):
# ---> 16     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#
# File /opt/conda/lib/python3.10/profile.py:53, in _Utils.run(self, statement, filename, sort)
#      51 prof = self.profiler()
#      52 try:
# ---> 53     prof.run(statement)
#      54 except SystemExit:
#      55     pass
#
# File /opt/conda/lib/python3.10/cProfile.py:95, in Profile.run(self, cmd)
#      93 import __main__
#      94 dict = __main__.__dict__
# ---> 95 return self.runctx(cmd, dict, dict)
#
# File /opt/conda/lib/python3.10/cProfile.py:100, in Profile.runctx(self, cmd, globals, locals)
#      98 self.enable()
#      99 try:
# --> 100     exec(cmd, globals, locals)
#     101 finally:
#     102     self.disable()
#
# File <string>:1
#
# Cell In[5], line 7, in produce_xy(producer, topic_name)
#       5 print(name)
#       6 publish_message(producer, topic_name, str(uuid.uuid4()), message)
# ----> 7 time.sleep(1)
#
# KeyboardInterrupt:
